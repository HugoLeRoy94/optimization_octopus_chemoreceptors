# %%
import sys
sys.path.append('/app')
from src.environment import *
import torch

# %%
n_units = 26
n_families = 1

# %%
env = LigandEnvironment(n_units=n_units,n_families=n_families).to('cuda')

# %%
env.interaction_mu.shape
# Out:
# torch.Size([26, 1, 2])

# %%
nrj,conc,idx = env.sample_batch(10)

# %%
nrj.shape
# Out:
# torch.Size([10, 26, 2])
